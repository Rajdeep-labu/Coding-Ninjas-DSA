# %% [markdown]
# ## L - Lecture, A - Assignment

# %% [markdown]
# ## Optimized way of taking input in LL(L)

# %%
class Node :
    def __init__(self,data):
        self.data = data        #data
        self.next = None        #reference
def printll(head):              #here head is not the same as head of taking input because it is a local variable to Printll 
    while head is not None:
        print(str(head.data) + '->',end = '')
        head =head.next
    print("None")
def takeinput():
    inputlist = [int(ele) for ele in input().split()]      #str to int 
    head = None
    tail = None
    for currdata in inputlist:
        if currdata == -1:            #will work for 1st element only 
            break
        
        newnode = Node(currdata)
        if head is None:
            head = newnode
            tail = newnode
        else:
            tail.next = newnode
            tail = newnode          # no need to traverse so we are maintaining a tail
            
    return head
head = takeinput()
printll(head)

# %% [markdown]
# ## Length of a node(iterative)(A)

# %%
from sys import stdin
#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None
    
def length(head) :
    temp = head
    count = 0                   #maintain a count at last we have to return the value
    while temp is not None:
        count += 1       
        temp = temp.next     
    return count


#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    print(length(head))

    t -= 1

# %% [markdown]
# ## Print ith node(A)

# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None




def printIthNode(head, i):
    curr = head 
    count = 0
    while curr is not None:
        if count == i:
            print(curr.data)
        count += 1
        curr = curr.next
        





#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    i = int(stdin.readline().rstrip())
    printIthNode(head, i)

    t -= 1

# %% [markdown]
# ## Insert at ith position (Iterative) (L)

# %%
#First create a length function to calculate length of LL

def insertati(head,i,length):
    if i < 0 or i > length(head): 
        return head
    count = 0
    prev = None
    curr = head
    while count < i:
        prev = curr
        curr = curr.next
        count += 1
        
    newnode = Node(currdata)
    if prev is not None:
        prev.next = newnode
    else:
        head = newnode
    newnode.next = curr
    
    return head    
#Write code for taking input as well
# TC = O(N)

# %% [markdown]
# ## Delete a Node (Iterative)(A)

# %%
from sys import stdin

# Following is the Node class already written for the Linked List.
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None


def deleteNode(head, pos) :
    if head is None:
        return head
    if pos == 0:
        return head.next
    count = 0
    curr = head
    while curr is not None and count < (pos - 1):
        count += 1
        curr.next = curr
    if curr is None or curr.next is None:
        return head 
    curr.next = curr.next.next
    
    return head



# Taking Input Using Fast I/O.
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



# To print the linked list.
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


# Main.
t = int(stdin.readline().strip())

while t > 0 :
    
    head = takeInput()
    pos = int(stdin.readline().rstrip())
    
    head = deleteNode(head, pos)
    printLinkedList(head)

    t -= 1

# %% [markdown]
# ## Length of a LinkedList(Recursive)(A)

# %%
from sys import stdin , setrecursionlimit
setrecursionlimit(10**6)
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
    
# Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


# To print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()

def lengthRecursive(head):
    # A linked list, find and return the length of input LL recursively.
    # Write your code here

    if head is None:
        return 0
    return 1 + lengthRecursive(head.next)

# Main
t = int(stdin.readline().rstrip())

while t > 0 :
    head = takeInput()
    ans=lengthRecursive(head)
    print(ans)
    t -= 1

# %% [markdown]
# ## Insert at ith position (Recursive) (L)

# %%
def insertAtIR(head,i,data):
    if i < 0:
        return head
    if  i == 0:
        newnode = Node(data)
        newNode.next = head
        return newNode
    
    if head is None:
        return None

    
    smallhead = insertAtIR(head.next,i -1 , data )
    head.next = smallhead
    return head
# TC = O(i) or max O(n)--> in case of head is nOne

# %% [markdown]
# ## Delete Node(Recursion)(A)

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10 ** 6)

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None


def deleteNodeRec(head, pos) :
    if head is None:
        return head
    if pos < 0:
        return head
    if pos == 0:
        return head.next
    if head == None:
        return None
    smalldelete = deleteNodeRec(head,pos -1)
    head.next = smalldelete
        




def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head




def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :
    
    head = takeInput()
    pos = int(stdin.readline().rstrip())    

    newHead = deleteNodeRec(head, pos)
    printLinkedList(newHead)

    t -= 1

# %% [markdown]
# ##
